# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series

# %%
df_bond2 = pd.read_csv("./final_data/original_data/bond_new.csv")

# %%
df_bond2.sort_values(['date'], ascending= False)
# Out:
#       Unnamed: 0      com        date  \
# 1394           0    hanaB  2017.12.27
# 1973           0  hyundai  2017.12.26
# 1393           0    hanaB  2017.12.20
# 1972           0  hyundai  2017.12.20
# 1971           0  hyundai  2017.12.18
# 1392           0    hanaB  2017.12.15
# 2887           0    kyobo  2017.12.15
# 622            0   ebest2  2017.12.14
# 3093           0    mirae  2017.12.14
# 1391           0    hanaB  2017.12.13
# 1970           0  hyundai  2017.12.08
# 1390           0    hanaB  2017.12.07
# 3092           0    mirae  2017.12.06
# 1969           0  hyundai  2017.12.04
# 1968           0  hyundai  2017.12.04
# 621            0   ebest2  2017.12.01
# 3091           0    mirae  2017.12.01
# 3090           0    mirae  2017.12.01
# 1967           0  hyundai  2017.12.01
# 620            0   ebest2  2017.11.30
# 2886           0    kyobo  2017.11.30
# 1389           0    hanaB  2017.11.29
# 2885           0    kyobo  2017.11.29
# ...

# %%
df_bond_count = pd.DataFrame({'counts': df_bond2.groupby('date').size()}).reset_index()

# %%
df_bond_count.to_csv("bond_count.csv", mode='w')

# %%
bond_pre = pd.read_csv('./bond_pre.csv')
bond_pre
# Out:
#       Unnamed: 0  Unnamed: 0.1     com        date  \
# 0              0             0    cape  2017.01.04
# 1              1             0    cape  2017.01.09
# 2              2             0    cape  2017.01.16
# 3              3             0    cape  2017.02.13
# 4              4             0    cape  2017.02.24
# 5              5             0    cape  2017.03.20
# 6              6             0    cape  2017.03.27
# 7              7             0    cape  2017.04.14
# 8              8             0    cape  2017.05.19
# 9              9             0    cape  2017.05.26
# 10            10             0    cape  2017.06.09
# 11            11             0    cape  2017.07.14
# 12            12             0  daewoo  2008.04.01
# 13            13             0  daewoo  2008.04.07
# 14            14             0  daewoo  2008.04.07
# 15            15             0  daewoo  2008.04.14
# 16            16             0  daewoo  2008.04.21
# ...

# %%
counts_all = bond_pre.groupby("com").size()
counts_all.to_csv("count_all.csv", mode='w')

# %%
df_1 = pd.read_csv("count_all.csv")
# Out:
#          DB    1
# 0    DB금융투자    1
# 1       IBK  527
# 2       KTB  186
# 3       LIG   42
# 4      cape   12
# 5    daewoo  539
# 6   daishin   37
# 7     ebest  424
# 8    ebest2   34
# 9    etrade   49
# 10    hanaA   22
# 11    hanaB  277
# 12   hanhwa   19
# 13  hyundai  560
# 14   kiwoom  176
# 15    kyobo   25
# 16   meritz   92
# 17    mirae   72

# %%
df_1["com"] = counts_y["com"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3108             try:
# -> 3109                 return libindex.get_value_box(s, key)
#    3110             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-209-510066d5d995> in <module>()
# ----> 1 df_1["com"] = counts_y["com"]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
# ...

# %%
bond_y = bond_pre[(bond_pre['date'] >= '2008.01.01')]
bond_y2 = bond_y[bond_y.date < '2009.01.01'] 
print(bond_y2)
# Out:
#       Unnamed: 0  Unnamed: 0.1     com        date  \
# 12            12             0  daewoo  2008.04.01
# 13            13             0  daewoo  2008.04.07
# 14            14             0  daewoo  2008.04.07
# 15            15             0  daewoo  2008.04.14
# 16            16             0  daewoo  2008.04.21
# 17            17             0  daewoo  2008.04.28
# 18            18             0  daewoo  2008.05.04
# 19            19             0  daewoo  2008.05.13
# 20            20             0  daewoo  2008.05.19
# 21            21             0  daewoo  2008.05.20
# 22            22             0  daewoo  2008.05.21
# 23            23             0  daewoo  2008.05.22
# 24            24             0  daewoo  2008.05.23
# 25            25             0  daewoo  2008.05.26
# 26            26             0  daewoo  2008.05.26
# 27            27             0  daewoo  2008.05.27
# 28            28             0  daewoo  2008.05.28
# ...

# %%
counts_y = bond_y2.groupby("com").size()
print(counts_y)
# counts_y.to_csv("counts_2008.csv", mode='w')
# Out:
# com
# daewoo    206
# hanaA       1
# dtype: int64
